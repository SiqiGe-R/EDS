# %% [markdown]
# # ECON62020 - Group Replication Project
#
# ## Group
#
# Guy Pigott - 8340277
# Trinity Rose - 14359078
# Siqi Ge - 14351973
#
# ## Replication Paper
#
# Friedberg, Leora and Isaac, Elliott, "Same-Sex Marriage Recognition and Taxes: New Evidence about the Impact of Household Taxation," The Review of Economics and Statistics (2024) 106 (1): 85–101
#
# ## Summary
#
# We will be replicating Table 3 which shows the baseline OLS and IV estimates of the effect of the marriage subsidy on the probability of being married, and Table A2 from the appendix of the paper which provides some summary statistics from the sample that is used.
